# %% [markdown]
# # Spatial Analisys - SWAN - Extreme Events in Significant Wave Height

# %% [markdown]
# ### Import bibs and SWN-ERA5EDA system

# %%
import numpy as np
import matplotlib as mpl
from scipy.io import loadmat  # this is the SciPy module that loads mat-files
import matplotlib.pyplot as plt
from datetime import datetime, date, time
import pandas as pd
import scipy.io as sio
import matplotlib.gridspec as gridspec
import cartopy.crs as ccrs
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import cartopy.feature as cfeature

# %%
############## MEMBRO ERA5 00 ##############

# Definir variáveis
par_mat0 = 'Hs_integ_2015_ensmbl_0.mat'
grid_mat0 = 'grid.mat'

# Importa output para um dicionário
mat0 = sio.loadmat(par_mat0) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid0 = sio.loadmat(grid_mat0)
drop0 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys0 = [key for key in mat0.keys() if key not in drop0] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons0 = grid0['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats0 = grid0['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 01 ##############

# Definir variáveis
par_mat1 = 'Hs_integ_2015_ensmbl_1.mat'
grid_mat1 = 'grid.mat'

# Importa output para um dicionário
mat1 = sio.loadmat(par_mat1) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid1 = sio.loadmat(grid_mat1)
drop1 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys1 = [key for key in mat1.keys() if key not in drop1] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons1 = grid1['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats1 = grid1['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 02 ##############

# Definir variáveis
par_mat2 = 'Hs_integ_2015_ensmbl_2.mat'
grid_mat2 = 'grid.mat'

# Importa output para um dicionário
mat2 = sio.loadmat(par_mat2) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid2 = sio.loadmat(grid_mat2)
drop2 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys2 = [key for key in mat2.keys() if key not in drop2] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons2 = grid2['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats2 = grid2['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 03 ##############

# Definir variáveis
par_mat3 = 'Hs_integ_2015_ensmbl_3.mat'
grid_mat3 = 'grid.mat'

# Importa output para um dicionário
mat3 = sio.loadmat(par_mat3) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid3 = sio.loadmat(grid_mat3)
drop3 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys3 = [key for key in mat3.keys() if key not in drop3] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons3 = grid3['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats3 = grid3['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 04 ##############

# Definir variáveis
par_mat4 = 'Hs_integ_2015_ensmbl_4.mat'
grid_mat4 = 'grid.mat'

# Importa output para um dicionário
mat4 = sio.loadmat(par_mat4) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid4 = sio.loadmat(grid_mat4)
drop4 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys4 = [key for key in mat4.keys() if key not in drop4] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons4 = grid0['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats4 = grid0['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 05 ##############

# Definir variáveis
par_mat5 = 'Hs_integ_2015_ensmbl_5.mat'
grid_mat5 = 'grid.mat'

# Importa output para um dicionário
mat5 = sio.loadmat(par_mat5) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid5 = sio.loadmat(grid_mat5)
drop5 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys5 = [key for key in mat5.keys() if key not in drop5] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons5 = grid5['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats5 = grid5['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 06 ##############

# Definir variáveis
par_mat6 = 'Hs_integ_2015_ensmbl_6.mat'
grid_mat6 = 'grid.mat'

# Importa output para um dicionário
mat6 = sio.loadmat(par_mat6) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid6 = sio.loadmat(grid_mat6)
drop6 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys6 = [key for key in mat6.keys() if key not in drop6] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons6 = grid6['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats6 = grid6['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 07 ##############

# Definir variáveis
par_mat7 = 'Hs_integ_2015_ensmbl_7.mat'
grid_mat7 = 'grid.mat'

# Importa output para um dicionário
mat7 = sio.loadmat(par_mat7) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid7 = sio.loadmat(grid_mat7)
drop7 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys7 = [key for key in mat7.keys() if key not in drop7] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons7 = grid7['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats7 = grid7['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 08 ##############

# Definir variáveis
par_mat8 = 'Hs_integ_2015_ensmbl_8.mat'
grid_mat8 = 'grid.mat'

# Importa output para um dicionário
mat8 = sio.loadmat(par_mat8) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid8 = sio.loadmat(grid_mat8)
drop8 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys8 = [key for key in mat8.keys() if key not in drop8] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons8 = grid8['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats8 = grid8['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 09 ##############

# Definir variáveis
par_mat9 = 'Hs_integ_2015_ensmbl_9.mat'
grid_mat9 = 'grid.mat'

# Importa output para um dicionário
mat9 = sio.loadmat(par_mat9) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid9 = sio.loadmat(grid_mat9)
drop9 = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys9 = [key for key in mat9.keys() if key not in drop9] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons9 = grid9['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats9 = grid9['Yp'] # seleciono latitude como a variável 'Yp' de grid

#teste = pd.DataFrame(np.hstack((par_mat0['Hsig_20150823_210000'])))

# %% [markdown]
# #### Substitute the date for one of the three desired events, such as:

# %% [markdown]
# Event 1: ['Hsig_20150725_160000']

# %% [markdown]
# Event 2: ['Hsig_20150810_060000']

# %% [markdown]
# Event 3: ['Hsig_20150823_200000']

# %%
## DICT TO DATAFRAME
mat0_pd = pd.DataFrame(mat0['Hsig_20150823_200000'])
mat1_pd = pd.DataFrame(mat1['Hsig_20150823_200000'])
mat2_pd = pd.DataFrame(mat2['Hsig_20150823_200000'])
mat3_pd = pd.DataFrame(mat3['Hsig_20150823_200000'])
mat4_pd = pd.DataFrame(mat4['Hsig_20150823_200000'])
mat5_pd = pd.DataFrame(mat5['Hsig_20150823_200000'])
mat6_pd = pd.DataFrame(mat6['Hsig_20150823_200000'])
mat7_pd = pd.DataFrame(mat7['Hsig_20150823_200000'])
mat8_pd = pd.DataFrame(mat8['Hsig_20150823_200000'])
mat9_pd = pd.DataFrame(mat9['Hsig_20150823_200000'])


### CALCULA MEDIA ESPACIAL DOS 10 MEMBROS

espacial_mean_ERA5 = (mat0_pd + mat1_pd + mat2_pd + mat3_pd + mat4_pd + mat5_pd + mat6_pd + mat7_pd + mat8_pd + mat9_pd) / 10

# %%
espacial_mean_ERA5.max().max()

# %% [markdown]
# ### Import bibs and SWN-WRFERA5 system

# %%
import numpy as np
from scipy.io import loadmat  # this is the SciPy module that loads mat-files
import matplotlib.pyplot as plt
from datetime import datetime, date, time
import pandas as pd
import scipy.io as sio

############## MEMBRO ERA5 00 ##############

# Definir variáveis
par_mat0_wrf = 'Hs_integ_WRF_ensmbl_0.mat'
grid_mat0_wrf = 'grid.mat'

# Importa output para um dicionário
mat0_wrf = sio.loadmat(par_mat0_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid0_wrf = sio.loadmat(grid_mat0_wrf)
drop0_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys0_wrf = [key for key in mat0_wrf.keys() if key not in drop0_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons0_wrf = grid0_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats0_wrf = grid0_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 01 ##############

# Definir variáveis
par_mat1_wrf = 'Hs_integ_WRF_ensmbl_1.mat'
grid_mat1_wrf = 'grid.mat'

# Importa output para um dicionário
mat1_wrf = sio.loadmat(par_mat1_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid1_wrf = sio.loadmat(grid_mat1_wrf)
drop1_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys1_wrf = [key for key in mat1_wrf.keys() if key not in drop1_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons1_wrf = grid1_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats1_wrf = grid1_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 02 ##############

# Definir variáveis
par_mat2_wrf = 'Hs_integ_WRF_ensmbl_2.mat'
grid_mat2_wrf = 'grid.mat'

# Importa output para um dicionário
mat2_wrf = sio.loadmat(par_mat2_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid2_wrf = sio.loadmat(grid_mat2_wrf)
drop2_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys2_wrf = [key for key in mat2_wrf.keys() if key not in drop2_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons2_wrf = grid2_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats2_wrf = grid2_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 03 ##############

# Definir variáveis
par_mat3_wrf = 'Hs_integ_WRF_ensmbl_3.mat'
grid_mat3_wrf = 'grid.mat'

# Importa output para um dicionário
mat3_wrf = sio.loadmat(par_mat3_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid3_wrf = sio.loadmat(grid_mat3_wrf)
drop3_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys3_wrf = [key for key in mat3_wrf.keys() if key not in drop3_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons3_wrf = grid3_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats3_wrf = grid3_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 04 ##############

# Definir variáveis
par_mat4_wrf = 'Hs_integ_WRF_ensmbl_4.mat'
grid_mat4_wrf = 'grid.mat'

# Importa output para um dicionário
mat4_wrf = sio.loadmat(par_mat4_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid4_wrf = sio.loadmat(grid_mat4_wrf)
drop4_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys4_wrf = [key for key in mat4_wrf.keys() if key not in drop4_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons4_wrf = grid4_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats4_wrf = grid4_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 05 ##############

# Definir variáveis
par_mat5_wrf = 'Hs_integ_WRF_ensmbl_5.mat'
grid_mat5_wrf = 'grid.mat'

# Importa output para um dicionário
mat5_wrf = sio.loadmat(par_mat5_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid5_wrf = sio.loadmat(grid_mat5_wrf)
drop5_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys5_wrf = [key for key in mat5_wrf.keys() if key not in drop5_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons5_wrf = grid5_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats5_wrf = grid5_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 06 ##############

# Definir variáveis
par_mat6_wrf = 'Hs_integ_WRF_ensmbl_6.mat'
grid_mat6_wrf = 'grid.mat'

# Importa output para um dicionário
mat6_wrf = sio.loadmat(par_mat6_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid6_wrf = sio.loadmat(grid_mat6_wrf)
drop6_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys6_wrf = [key for key in mat6_wrf.keys() if key not in drop6_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons6_wrf = grid6_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats6_wrf = grid6_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 07 ##############

# Definir variáveis
par_mat7_wrf = 'Hs_integ_WRF_ensmbl_7.mat'
grid_mat7_wrf = 'grid.mat'

# Importa output para um dicionário
mat7_wrf = sio.loadmat(par_mat7_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid7_wrf = sio.loadmat(grid_mat7_wrf)
drop7_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys7_wrf = [key for key in mat7_wrf.keys() if key not in drop7_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons7_wrf = grid7_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats7_wrf = grid7_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 08 ##############

# Definir variáveis
par_mat8_wrf = 'Hs_integ_WRF_ensmbl_8.mat'
grid_mat8_wrf = 'grid.mat'

# Importa output para um dicionário
mat8_wrf = sio.loadmat(par_mat8_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid8_wrf = sio.loadmat(grid_mat8_wrf)
drop8_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys8_wrf = [key for key in mat8_wrf.keys() if key not in drop8_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons8_wrf = grid8_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats8_wrf = grid8_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO ERA5 09 ##############

# Definir variáveis
par_mat9_wrf = 'Hs_integ_WRF_ensmbl_9.mat'
grid_mat9_wrf = 'grid.mat'

# Importa output para um dicionário
mat9_wrf = sio.loadmat(par_mat9_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid9_wrf = sio.loadmat(grid_mat9_wrf)
drop9_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys9_wrf = [key for key in mat9_wrf.keys() if key not in drop9_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons9_wrf = grid9_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats9_wrf = grid9_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

# %% [markdown]
# #### Substitute the date for one of the three desired events, such as:

# %% [markdown]
# Event 1: ['Hsig_20150725_160000']

# %% [markdown]
# Event 2: ['Hsig_20150810_060000']

# %% [markdown]
# Event 3: ['Hsig_20150823_200000']

# %%
mat0_pd_wrf = pd.DataFrame(mat0_wrf['Hsig_20150823_200000'])
mat1_pd_wrf = pd.DataFrame(mat1_wrf['Hsig_20150823_200000'])
mat2_pd_wrf = pd.DataFrame(mat2_wrf['Hsig_20150823_200000'])
mat3_pd_wrf = pd.DataFrame(mat3_wrf['Hsig_20150823_200000'])
mat4_pd_wrf = pd.DataFrame(mat4_wrf['Hsig_20150823_200000'])
mat5_pd_wrf = pd.DataFrame(mat5_wrf['Hsig_20150823_200000'])
mat6_pd_wrf = pd.DataFrame(mat6_wrf['Hsig_20150823_200000'])
mat7_pd_wrf = pd.DataFrame(mat7_wrf['Hsig_20150823_200000'])
mat8_pd_wrf = pd.DataFrame(mat8_wrf['Hsig_20150823_200000'])
mat9_pd_wrf = pd.DataFrame(mat9_wrf['Hsig_20150823_200000'])

espacial_mean_WRF = (mat0_pd_wrf + mat1_pd_wrf + mat2_pd_wrf + mat3_pd_wrf + mat4_pd_wrf + mat5_pd_wrf + mat6_pd_wrf + mat7_pd_wrf + mat8_pd_wrf + mat9_pd_wrf) / 10

# %%
espacial_mean_WRF.max().max()

# %% [markdown]
# ### Import bibs and SWN-WRFPPar system

# %%
import numpy as np
from scipy.io import loadmat  # this is the SciPy module that loads mat-files
import matplotlib.pyplot as plt
from datetime import datetime, date, time
import pandas as pd
import scipy.io as sio
############## MEMBRO WRF Disturb. 10 ##############

# Definir variáveis
par_mat10_wrf = 'Hs_integ_WRF_ensmbl_10.mat'
grid_mat10_wrf = 'grid.mat'

# Importa output para um dicionário
mat10_wrf = sio.loadmat(par_mat10_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid10_wrf = sio.loadmat(grid_mat10_wrf)
drop10_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys10_wrf = [key for key in mat10_wrf.keys() if key not in drop10_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons10_wrf = grid10_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats10_wrf = grid10_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO WRF Disturb. 11 ##############

# Definir variáveis
par_mat11_wrf = 'Hs_integ_WRF_ensmbl_11.mat'
grid_mat11_wrf = 'grid.mat'

# Importa output para um dicionário
mat11_wrf = sio.loadmat(par_mat11_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid11_wrf = sio.loadmat(grid_mat11_wrf)
drop11_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys11_wrf = [key for key in mat11_wrf.keys() if key not in drop11_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons11_wrf = grid11_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats11_wrf = grid11_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO WRF Disturb. 12 ##############

# Definir variáveis
par_mat12_wrf = 'Hs_integ_WRF_ensmbl_12.mat'
grid_mat12_wrf = 'grid.mat'

# Importa output para um dicionário
mat12_wrf = sio.loadmat(par_mat12_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid12_wrf = sio.loadmat(grid_mat12_wrf)
drop12_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys12_wrf = [key for key in mat12_wrf.keys() if key not in drop12_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons12_wrf = grid12_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats12_wrf = grid12_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

############## MEMBRO WRF Disturb. 13 ##############

# Definir variáveis
par_mat13_wrf = 'Hs_integ_WRF_ensmbl_13.mat'
grid_mat13_wrf = 'grid.mat'

# Importa output para um dicionário
mat13_wrf = sio.loadmat(par_mat13_wrf) # se quiser checar quais variáveis estão presentes, digita mat.keys() em uma nova célula
grid13_wrf = sio.loadmat(grid_mat13_wrf)
drop13_wrf = ['__header__', '__version__', '__globals__'] # variáveis que não quero

keys13_wrf = [key for key in mat13_wrf.keys() if key not in drop13_wrf] # seleciono as variáveis que quero, ou seja, que não estão em drop
lons13_wrf = grid13_wrf['Xp'] # seleciono longitude como a variável 'Xp' de grid
lats13_wrf = grid13_wrf['Yp'] # seleciono latitude como a variável 'Yp' de grid

# %% [markdown]
# #### Substitute the date for one of the three desired events, such as:

# %% [markdown]
# Event 1: ['Hsig_20150725_160000']

# %% [markdown]
# Event 2: ['Hsig_20150810_060000']

# %% [markdown]
# Event 3: ['Hsig_20150823_200000']

# %%
### TRANSFORMA DICT PARA DATAFRAME

mat10_pd_wrf = pd.DataFrame(mat10_wrf['Hsig_20150823_200000'])
mat11_pd_wrf = pd.DataFrame(mat11_wrf['Hsig_20150823_200000'])
mat12_pd_wrf = pd.DataFrame(mat12_wrf['Hsig_20150823_200000'])
mat13_pd_wrf = pd.DataFrame(mat13_wrf['Hsig_20150823_200000'])


### CALCULA MEDIA ESPACIAL DOS 10 MEMBROS

espacial_mean_WRF_NEW = (mat10_pd_wrf + mat11_pd_wrf + mat12_pd_wrf + mat13_pd_wrf) / 4

# %%
espacial_mean_WRF_NEW.max().max()

# %% [markdown]
# ### Individual spatial plot

# %% [markdown]
# #### Replace in "plt.contourf" the encemble system to be plotted

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature

ax = plt.axes(projection=ccrs.PlateCarree())
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES, linestyle = ':')
gl = ax.gridlines(draw_labels=True, linestyle = ':', color = 'dimgray')
gl.top_labels = False
gl.right_labels = False
gl.bottom_labels = False
gl.left_labels = False

plt.contourf(lons10_wrf, lats10_wrf, espacial_mean_ERA5, 6,
             transform=ccrs.PlateCarree())
ax.set_extent([-55, -45, -37, -25])
ax.coastlines()

plt.colorbar(ticks=[0, 1.5, 3, 4.5, 6, 7.5])
plt.savefig('EnsMean_SWNERA5EDA_event1.png', format='png', dpi = 600)
